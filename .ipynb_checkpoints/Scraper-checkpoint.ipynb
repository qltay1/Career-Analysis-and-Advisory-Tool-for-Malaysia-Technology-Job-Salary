# %%
import pandas as pd 
import numpy as np
import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
import chromedriver_binary

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("--disable-blink-features=AutomationControlled")

# %%
url = 'https://malaysia.indeed.com/'

driver = webdriver.Chrome()

webdriver = driver.get(url)

major_soup = BeautifulSoup(driver.page_source , 'html.parser')

user_agent = 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.92 Safari/537.36'

pages = [str(num) for num in range(10,50, 10)]

headers={'User-Agent':user_agent}

global pages, headers

search = driver.find_element_by_xpath('//*[@id="text-input-what"]').send_keys('Product Engineer')

proceed = driver.find_element_by_xpath('/html/body/div[1]/div[2]/span/div[3]/div[1]/div/div/div/form/div[3]/button').click()

# %%
job_title = []
company = []

def scrape_job():
    user_agent = 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.92 Safari/537.36'
    headers={'User-Agent':user_agent}
    pages = [str(num) for num in range(10,50, 10)]



    
    for page in pages:
        individual_webpage = requests.get('https://malaysia.indeed.com/jobs?q=Product+Engineer&sort=date&start=' + page , headers=headers)
        soup = BeautifulSoup(individual_webpage.content,'html.parser')
        job_main_content = soup.find_all('div' , class_ = 'job_seen_beacon').find_all('table' , class_='jobCard_mainContent')
        
        print(slider)
        for s in slider:
            job = s.find_all('h2', class_='jobTitle jobTitle-color-purple jobTitle-newJob')
            company = s.find_all('div', class_='heading6 company_location tapItem-gutter')

            
            for a in job:
                if a != None:
                    child = a.find_all('span')[1]
                    job_title.append(child.text)
        
            for b in company:
                if b != None:
                    child = b.find('span', class_='companyName')
                    company.append(child.text)
                
    return job_title,company

# %%
import re
user_agent = 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.92 Safari/537.36'

pages = [str(num) for num in range(10,50, 10)]

headers={'User-Agent':user_agent}

individual_webpage = requests.get('https://malaysia.indeed.com/jobs?q=Product+Engineer&sort=date&start=' + '20' , headers=headers)
soup = BeautifulSoup(individual_webpage.content,'html.parser')
table1 = soup.find_all('table' , class_='jobCard_mainContent')
table2 = soup.find_all('table' , class_ = 'jobCardShelfContainer')
'''
temp = []
for b in table1:
    
    result = b.find('a', class_='turnstileLink companyOverviewLink')
    if result == None:
        result = 'Unknown'
    else:
        
        result =  result['href'].strip('/cmp/')
    
    temp.append(result)
'''
#for a in table1:
    #print(a.find('h2' , class_='jobTitle jobTitle-color-purple jobTitle-newJob').text.lstrip('new'))
#    print(a.find('h2').text.strip('new'))

temp = []
'''
for c in table1:
    result = c.find('span', class_='ratingNumber')
    if result == None:
        result = np.nan
    else:
        result = float(result.find('span', 'aria-hidden'== True).text)
        #print(result)
    
    temp.append(result)

for c in table1:
    result = c.find('div', class_='companyLocation')
    if result == None:
        result = ''
    else:
        #result = re.sub('',r'w\+\\+',result.text)
        print(result)
    
    temp.append(result)
'''
temp = []
'''
for d in table1:
    result = d.find('span', class_='salary-snippet')
    if result ==None:
        result = 0
    else:
        result = result.text
    
    temp.append(result)
'''

for e in table2:
    result = e.find_all('li')
    for f in result:
        print(f)
    #print(result)
temp
# Out:
# <li>With a 25-year history and presence across Six (6) Asian countries, FVG is in a strong position to strengthen its market leadership in its core acoustic…</li>
# <li><span class="mat">View all <a href="/Flexi-Components-(kedah)-Sdn-Bhd-jobs">FLEXI COMPONENTS (KEDAH) SDN BHD jobs</a> - <a href="/jobs-in-Sungai-Petani">Sungai Petani jobs</a></span></li>
# <li><span class="mat">Salary Search: <a href="/career/salaries/Junior%20Engineer/Sungai%20Petani?campaignid=serp-more&amp;fromjk=bb4e256021addbe7&amp;from=serp-more">Junior Engineer Assistant (Male) salaries</a></span></li>
# <li style="margin-bottom:0px;">Meiban Technologies serves automotive, medical, and consumer <b>product</b> industries worldwide.</li>
# <li> Study FAI report for dimensional rectification according product…</li>
# <li><span class="mat">View all <a href="/Meiban-Technologies-(malaysia)-Sdn-Bhd-jobs">MEIBAN TECHNOLOGIES (MALAYSIA) SDN BHD jobs</a> - <a href="/jobs-in-Ulu-Tiram">Ulu Tiram jobs</a></span></li>
# ...

# %%
job_title = []
company = []

def scrape_job():
    user_agent = 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.92 Safari/537.36'
    headers={'User-Agent':user_agent}
    pages = [str(num) for num in range(10,50, 10)]



    
    for page in pages:
        individual_webpage = requests.get('https://malaysia.indeed.com/jobs?q=Product+Engineer&sort=date&start=' + page , headers=headers)
        soup = BeautifulSoup(individual_webpage.content,'html.parser')
    
        job = soup.find_all('h2', class_='jobTitle jobTitle-color-purple jobTitle-newJob')
        
        company = soup.find_all('div', class_='heading6 company_location tapItem-gutter')
        
        for a in job:
            if a != None:
                child = a.find_all('span')[1]
                job_title.append(child.text)
        
        for b in company:
            if b != None:
                child = b.find('span', class_='companyName')
                company.append(child.text)
                
        return job_title,company
